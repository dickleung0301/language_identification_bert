# %%
from google.colab import drive
drive.mount('/content/drive/')

# %%
# %cd /content/drive/My Drive/Colab Notebooks/language_identification_bert/n_gram_lang_id_baseline

# %%
# !pip install dotenv

# %%
# !pip install datasets

# %%
# !pip install transformers

# %%
# !pip install evaluate

# %%
# !pip install peft

# %%
# !python main.py --infer -n 2 -top_k 400 -penalties 400 -doc_path "../input_documents/arabic.txt"
# Out:
# The document is written in arabic:)!
# The languages with the smallest 3 distance are:
# arabic: 55183
# urdu: 78910
# italian: 117123

# %%
# !python main.py --infer -n 2 -top_k 400 -penalties 400 -doc_path "../input_documents/bulgarian.txt"
# Out:
# The document is written in bulgarian:)!
# The languages with the smallest 3 distance are:
# bulgarian: 32731
# russian: 42582
# italian: 118193

# %%
# !python main.py --infer -n 2 -top_k 400 -penalties 400 -doc_path "../input_documents/chinese.txt"
# Out:
# The document is written in chinese:)!
# The languages with the smallest 3 distance are:
# chinese: 84250
# italian: 85337
# portuguese: 85674

# %%
# !python main.py --infer -n 2 -top_k 400 -penalties 400 -doc_path "../input_documents/dutch.txt"
# Out:
# The document is written in dutch:)!
# The languages with the smallest 3 distance are:
# dutch: 17969
# english: 27449
# german: 29461

# %%
# !python main.py --infer -n 2 -top_k 400 -penalties 400 -doc_path "../input_documents/english.txt"
# Out:
# The document is written in english:)!
# The languages with the smallest 3 distance are:
# english: 41273
# dutch: 49677
# italian: 52368

# %%
# !python main.py --infer -n 2 -top_k 400 -penalties 400 -doc_path "../input_documents/french.txt"
# Out:
# The document is written in french:)!
# The languages with the smallest 3 distance are:
# french: 33153
# italian: 41866
# portuguese: 45179

# %%
# !python main.py --infer -n 2 -top_k 400 -penalties 400 -doc_path "../input_documents/german.txt"
# Out:
# The document is written in german:)!
# The languages with the smallest 3 distance are:
# german: 32344
# dutch: 43707
# english: 48251

# %%
# !python main.py --infer -n 2 -top_k 400 -penalties 400 -doc_path "../input_documents/greek.txt"
# Out:
# The document is written in modern greek:)!
# The languages with the smallest 3 distance are:
# modern greek: 55842
# italian: 153823
# german: 154532

# %%
# !python main.py --infer -n 2 -top_k 400 -penalties 400 -doc_path "../input_documents/hindi.txt"
# Out:
# The document is written in hindi:)!
# The languages with the smallest 3 distance are:
# hindi: 84181
# swahili: 155177
# italian: 155489

# %%
# !python main.py --infer -n 2 -top_k 400 -penalties 400 -doc_path "../input_documents/italian.txt"
# Out:
# The document is written in italian:)!
# The languages with the smallest 3 distance are:
# italian: 25850
# portuguese: 36107
# dutch: 37353

# %%
# !python main.py --infer -n 2 -top_k 400 -penalties 400 -doc_path "../input_documents/japanese.txt"
# Out:
# The document is written in japanese:)!
# The languages with the smallest 3 distance are:
# japanese: 139519
# dutch: 156415
# portuguese: 156556

# %%
# !python main.py --infer -n 2 -top_k 400 -penalties 400 -doc_path "../input_documents/polish.txt"
# Out:
# The document is written in polish:)!
# The languages with the smallest 3 distance are:
# polish: 43021
# dutch: 90028
# swahili: 91661

# %%
# !python main.py --infer -n 2 -top_k 400 -penalties 400 -doc_path "../input_documents/portuguese.txt"
# Out:
# The document is written in portuguese:)!
# The languages with the smallest 3 distance are:
# portuguese: 29252
# spanish: 34115
# italian: 36586

# %%
# !python main.py --infer -n 2 -top_k 400 -penalties 400 -doc_path "../input_documents/russian.txt"
# Out:
# The document is written in russian:)!
# The languages with the smallest 3 distance are:
# russian: 63569
# bulgarian: 77918
# italian: 143667

# %%
# !python main.py --infer -n 2 -top_k 400 -penalties 400 -doc_path "../input_documents/thai.txt"
# Out:
# The document is written in thai:)!
# The languages with the smallest 3 distance are:
# thai: 97738
# italian: 156569
# swahili: 156942

# %%
# !python main.py --infer -n 2 -top_k 400 -penalties 400 -doc_path "../input_documents/turkish.txt"
# Out:
# The document is written in turkish:)!
# The languages with the smallest 3 distance are:
# turkish: 41709
# swahili: 72648
# italian: 72950

# %%
# !python main.py --infer -n 2 -top_k 400 -penalties 400 -doc_path "../input_documents/urdu.txt"
# Out:
# The document is written in urdu:)!
# The languages with the smallest 3 distance are:
# urdu: 62948
# arabic: 98015
# dutch: 145813

# %%
# !python main.py --infer -n 2 -top_k 400 -penalties 400 -doc_path "../input_documents/vietnamese.txt"
# Out:
# The document is written in vietnamese:)!
# The languages with the smallest 3 distance are:
# vietnamese: 86066
# italian: 132605
# spanish: 133373
